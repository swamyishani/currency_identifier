# %%
# !nvidia-smi
# Out:
# Sun Apr 26 16:07:00 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 31.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# Installing libraries required

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
import glob
display.clear_output()
# !yolo checks
# Out:
# Ultralytics 8.4.41 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 43.0/112.6 GB disk)
#
# OS                     Linux-6.6.113+-x86_64-with-glibc2.35
# Environment            Colab
# Python                 3.12.13
# Install                pip
# Path                   /usr/local/lib/python3.12/dist-packages/ultralytics
# RAM                    12.67 GB
# Disk                   43.0/112.6 GB
# CPU                    Intel Xeon CPU @ 2.00GHz
# CPU count              2
# GPU                    Tesla T4, 14913MiB
# GPU count              1
# CUDA                   12.8
#
# numpy                  ✅ 2.0.2>=1.23.0
# matplotlib             ✅ 3.10.0>=3.3.0
# opencv-python          ✅ 4.13.0.92>=4.6.0
# pillow                 ✅ 11.3.0>=7.1.2
# pyyaml                 ✅ 6.0.3>=5.3.1
# requests               ✅ 2.32.4>=2.23.0
# scipy                  ✅ 1.16.3>=1.4.1
# torch                  ✅ 2.10.0+cu128>=1.8.0
# ...

# %% [markdown]
# Training Yolov8 model

# %%
# !wget -o /content/archive.zip https://www.kaggle.com/datasets/danielrajchristeen/indian-currency-recognition

# %%
# !unzip "/content/archive.zip" -d /content/data
# Out:
# Archive:  /content/archive (1).zip
#   inflating: /content/data/README.dataset.txt
#   inflating: /content/data/README.roboflow.txt
#   inflating: /content/data/data.yaml
#   inflating: /content/data/test/images/100_14_jpeg.rf.d594563f2073ddcc694ffffd3b4ebe5a.jpg
#   inflating: /content/data/test/images/100_21_jpeg.rf.1c3199d01ecdd47c7cfa7b80c97edece.jpg
#   inflating: /content/data/test/images/100_45-copy-_jpeg.rf.c2751df185e38e754b2a9b0aa82d3032.jpg
#   inflating: /content/data/test/images/1010_jpg.rf.8f4b770f4a86ec2b225a2832077afc32.jpg
#   inflating: /content/data/test/images/1015_jpg.rf.d5a491a59948546c6a10538c1fc9145d.jpg
#   inflating: /content/data/test/images/1016_jpg.rf.6ce8da28751dc9dc9747554bd15dd38b.jpg
#   inflating: /content/data/test/images/1023_jpg.rf.8e6946bc9ac3978207a0d9630b4f7100.jpg
#   inflating: /content/data/test/images/1026_jpg.rf.b3c9227c305083d52dd8ade093ab9ac3.jpg
#   inflating: /content/data/test/images/1046_jpg.rf.9fe89b315ebc7139b73a4aece501d08f.jpg
# ...

# %%
# !yolo detect train data=/content/data/data.yaml model=yolov8n.pt epochs=250 imgsz=640
# Out:
# Ultralytics 8.4.41 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %% [markdown]
# Testing the model

# %%
# !yolo detect predict model=runs/detect/train/weights/best.pt source=data/valid/images save=True

output_dir = 'runs/detect/predict'
predicted_image_paths = glob.glob(f'{output_dir}/*.jpg')[:10]

for image_path in predicted_image_paths:
  display(Image(filename=image_path,height=400))
  print("\n")
# Out:
# Ultralytics 8.4.41 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,007,208 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/373 /content/data/valid/images/1004_jpg.rf.7befbc71c6577ddf3f70f1ddf453d236.jpg: 640x640 1 200, 9.0ms
# image 2/373 /content/data/valid/images/1008_jpg.rf.03922fd9ab0fb8ca8b235cb896be58d7.jpg: 640x640 1 200, 7.1ms
# image 3/373 /content/data/valid/images/100_11_jpeg.rf.c473fd2a7e413847e462dff52b37f734.jpg: 640x640 2 100s, 1 500, 7.0ms
# image 4/373 /content/data/valid/images/100_20_jpeg.rf.83dbc41a702fb18d5c35c20fb72897cb.jpg: 640x640 4 100s, 7.0ms
# image 5/373 /content/data/valid/images/100_24_jpeg.rf.556ac89be9fee352e9d7865f98a14a18.jpg: 640x640 2 100s, 7.0ms
# image 6/373 /content/data/valid/images/100_37_jpeg.rf.621cad52cbcd86c4a83ce0cfaead0349.jpg: 640x640 2 100s, 7.0ms
# image 7/373 /content/data/valid/images/1019_jpg.rf.561e79cf806acf69a023c9e83733ad9d.jpg: 640x640 1 200, 7.1ms
# ...

# %% [markdown]
# Downloading model

# %%
# !mkdir /content/currency_identifier
# !cp /content/runs/detect/train-2/weights/best.pt /content/currency_identifier/currency_identifier.pt
# !cp -r /content/runs/detect/train-2 /content/currency_identifier

# %cd currency_identifier
# !zip /content/currency_identifier.zip currency_identifier.pt
# !zip -r /content/currency_identifier.zip train-2
# %cd /content
# Out:
# /content/currency_identifier
#   adding: currency_identifier.pt (deflated 10%)
#   adding: train-2/ (stored 0%)
#   adding: train-2/labels.jpg (deflated 19%)
#   adding: train-2/BoxPR_curve.png (deflated 14%)
#   adding: train-2/confusion_matrix.png (deflated 26%)
#   adding: train-2/val_batch2_pred.jpg (deflated 10%)
#   adding: train-2/BoxF1_curve.png (deflated 8%)
#   adding: train-2/confusion_matrix_normalized.png (deflated 22%)
#   adding: train-2/val_batch0_labels.jpg (deflated 11%)
#   adding: train-2/results.png (deflated 8%)
#   adding: train-2/train_batch0.jpg (deflated 5%)
#   adding: train-2/val_batch0_pred.jpg (deflated 11%)
#   adding: train-2/val_batch2_labels.jpg (deflated 11%)
#   adding: train-2/results.csv (deflated 64%)
#   adding: train-2/weights/ (stored 0%)
#   adding: train-2/weights/last.pt (deflated 10%)
#   adding: train-2/weights/best.pt (deflated 10%)
#   adding: train-2/BoxP_curve.png (deflated 10%)
#   adding: train-2/args.yaml (deflated 53%)
# ...
